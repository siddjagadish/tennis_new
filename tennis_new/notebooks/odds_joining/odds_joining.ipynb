# %% [markdown]
# ## Odds Joining (OLD: 2018 Only)
#
# The purpose of this notebook is to determine how to join odds data, from [here](http://www.tennis-data.co.uk/alldata.php), with the parsed data.  This is difficult because player's names are represented differently, the parsed data doesn't have match dates, tournaments are represented differently, and so on.  There are various manual corrections we will need to make to create our basis for joining the data here.
#
# Here, we join by player name, tournament, and score.  This produces a dataframe called merged_2018.csv

# %% [markdown]
# #### Joining Odds Data to My Data

# %%
import pandas as pd
from tennis_new.fetch.get_joined import read_joined

odds_df = pd.read_csv("/Users/siddhantjagadish/Downloads/2018.csv")
jd = read_joined()
# Out:
# /Users/siddhantjagadish/Documents/DataProjects/tennis_new/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
jd.shape, odds_df.shape
# Out:
# ((373236, 28), (2637, 40))

# %% [markdown]
# #### Explore Odds Data

# %%
odds_df.head()
# Out:
#    ATP  Location              Tournament      Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International  12/31/17  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International  12/31/17  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International    1/1/18  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International    1/1/18  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International    1/1/18  ATP250  Outdoor    Hard
#
#        Round  Best of         Winner  ...   EXW   EXL   LBW   LBL   PSW   PSL  \
# 0  1st Round        3  Dolgopolov O.  ...  2.10  1.65  2.20  1.67  2.24  1.71
# 1  1st Round        3   De Minaur A.  ...  2.80  1.38  2.75  1.44  3.14  1.41
# 2  1st Round        3    Harrison R.  ...  1.62  2.15  1.67  2.20  1.66  2.35
# 3  1st Round        3       Ebden M.  ...  2.35  1.53  2.37  1.57  2.38  1.64
# 4  1st Round        3      Zverev M.  ...  1.47  2.50  1.57  2.37  1.44  3.00
#
#    MaxW  MaxL  AvgW  AvgL
# 0  2.29  1.77  2.17  1.68
# 1  3.25  1.44  2.96  1.39
# 2  1.75  2.35  1.67  2.17
# 3  2.52  1.65  2.37  1.58
# 4  1.57  3.00  1.44  2.73
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Name Processing
#
# Let's process the player's names so we can join on them

# %%
JD_NAME_CORRECTIONS = {
    'MARTIN DEL POTRO': 'DEL POTRO',
    'IGNACIO LONDERO': 'LONDERO',
    'AL-MUTAWA': 'AL MUTAWA',
    'FERREIRA SILVA': "SILVA",
    "ELAHI GALAN": "GALAN"
}

# %%
# Preprocessing for upper case
jd['winner_name'] = jd['winner_name'].map(lambda x: x.upper())
jd['loser_name'] = jd['loser_name'].map(lambda x: x.upper())
odds_df['Winner'] = odds_df['Winner'].map(lambda x: x.upper())
odds_df['Loser'] = odds_df['Loser'].map(lambda x: x.upper())

# %%
def last_name_jd(n):
    return ' '.join(n.upper().split(' ')[1:])

def last_name_odds(n):
    return ' '.join(n.upper().split(' ')[: -1])

jd['winner_last_name'] = jd['winner_name'].map(last_name_jd)
jd['loser_last_name'] = jd['loser_name'].map(last_name_jd)
jd['winner_last_name'] = jd['winner_last_name'].map(lambda x: JD_NAME_CORRECTIONS.get(x, x))
jd['loser_last_name'] = jd['loser_last_name'].map(lambda x: JD_NAME_CORRECTIONS.get(x, x))

# %%
odds_df['winner_last_name'] = odds_df['Winner'].map(last_name_odds)
odds_df['loser_last_name'] = odds_df['Loser'].map(last_name_odds)

# %%
top_missing_winners = odds_df['Winner'][~odds_df['winner_last_name'].isin(jd['winner_last_name'])].value_counts()
top_missing_winners
# Out:
# Series([], Name: Winner, dtype: int64)

# %%
top_missing_losers = odds_df['Loser'][~odds_df['loser_last_name'].isin(jd['loser_last_name'])].value_counts()
top_missing_losers
# Out:
# Series([], Name: Loser, dtype: int64)

# %%
PROBLEM_NAME = 'AL MUTAWA J.'
odds_df[odds_df['Loser'] == PROBLEM_NAME]
# Out:
#     ATP Location              Tournament    Date  Series    Court Surface  \
# 39    2     Doha  QATAR EXXON MOBIL OPEN  1/2/18  ATP250  Outdoor    Hard
#
#         Round  Best of        Winner         Loser  WRank  LRank  WPts  LPts  \
# 39  1st Round        3  TRAVAGLIA S.  AL MUTAWA J.    134    NaN   414   NaN
#
#      W1   L1   W2   L2  W3  L3  W4  L4  W5  L5  Wsets  Lsets    Comment  \
# 39  6.0  1.0  6.0  2.0 NaN NaN NaN NaN NaN NaN    2.0    0.0  Completed
#
#     B365W  B365L  EXW  EXL   LBW   LBL   PSW    PSL  MaxW  MaxL  AvgW   AvgL  \
# 39  1.005   34.0  NaN  NaN  1.01  26.0  1.01  25.62  1.02  34.0  1.01  18.89
#
#    winner_last_name loser_last_name  odds_match_id
# 39        TRAVAGLIA       AL MUTAWA             39

# %%
odds_df[['Loser', 'loser_last_name']][
    odds_df['Loser'].isin(top_missing_losers.index)
].drop_duplicates('Loser')
# Out:
# Empty DataFrame
# Columns: [Loser, loser_last_name]
# Index: []

# %% [markdown]
# #### Tournament Mapping
#
# The tournament names are presented differently as well.  We will have to map tournament names to each other to provide the right mappings...

# %%
# Preprocessing, don't wanna deal with case issues

jd['tourney_title'] = jd['tourney_title'].map(lambda x: x.upper())
odds_df['Tournament'] = odds_df['Tournament'].map(lambda x: x.upper().strip(' '))

# %%
odds_df['Tournament'][~odds_df['Tournament'].isin(jd['tourney_title'])].value_counts().head()
# Out:
# FRENCH OPEN            127
# SONY ERICSSON OPEN      95
# ROGERS MASTERS          55
# MONTE CARLO MASTERS     55
# SHANGHAI MASTERS        55
# Name: Tournament, dtype: int64

# %%
pd.set_option('display.max_rows', 100, 'display.max_columns', None) # more options can be specified also
wubba = odds_df.groupby(['Tournament', 'Location']).apply(
    lambda x: pd.Series({
        'n_matches': x.shape[0],
        'min_date': x['Date'].min()
    })
).sort_values('n_matches', ascending=False)
wubba
# Out:
#                                                                n_matches  \
# Tournament                                   Location
# WIMBLEDON                                    London                  127
# US OPEN                                      New York                127
# AUSTRALIAN OPEN                              Melbourne               127
# GAZPROM HUNGARIAN OPEN                       Budapest           4/23/18
# GENERALI OPEN                                Kitzbuhel          7/30/18
# OPEN DE MOSELLE                              Metz               9/17/18
# GENEVA OPEN                                  Geneva             5/20/18
# GARANTI KOZA SOFIA OPEN                      Sofia              2/10/18
# BRISBANE INTERNATIONAL                       Brisbane            1/1/18
# EUROPEAN OPEN                                Antwerp           10/15/18
# HALL OF FAME CHAMPIONSHIPS                   Newport            7/16/18
# ABIERTO MEXICANO MIFEL                       Los Cabos          7/31/18
# ISTANBUL OPEN                                Istanbul           4/30/18
# KREMLIN CUP                                  Moscow            10/15/18
# LYON OPEN                                    Lyon               5/20/18
# MERCEDES CUP                                 Stuttgart          6/11/18
# MILLENNIUM ESTORIL OPEN                      Estoril            4/30/18
# BRASIL OPEN                                  Sao Paulo          2/26/18
# CHENGDU OPEN                                 Chengdu            9/24/18
# NEW YORK OPEN                                New York           2/12/18
# OPEN 13                                      Marseille          2/19/18
# BMW OPEN                                     Munich             4/30/18
# OPEN SUD DE FRANCE                           Montpellier        2/10/18
# MASTERS CUP                                  London            11/11/18

# %%
def tourney_stats(s):
    tourney_titles = jd[
        jd['tourney_title'].map(lambda x: s in x) &
        (jd['tour_type'] == 'atp')
    ]['tourney_title'].unique()
    rel = jd[
        jd['tourney_title'].isin(tourney_titles) &
        (jd['tour_type'] == 'atp')
    ]
    print(rel['tourney_title'].value_counts())
    print(rel.groupby('tourney_title').apply(lambda x: (x['tourney_dates'].min(), x['tourney_dates'].max())))
    
tourney_stats("BNP")
# Out:
# BNP PARIBAS OPEN    131
# Name: tourney_title, dtype: int64
# tourney_title
# BNP PARIBAS OPEN    (2019.03.07, 2019.03.07)
# dtype: object

# %%
# To help with joining odds data...
TOURNAMENT_MAPPING = {
    'BRISBANE INTERNATIONAL': ['BRISBANE', 'BRISBANE INTERNATIONAL'],
    'US OPEN': 'US OPEN',
    'WIMBLEDON': 'WIMBLEDON',
    'FRENCH OPEN': 'ROLAND GARROS',
    'AUSTRALIAN OPEN': ['AUSTRALIAN OPEN',  'AUSTRALIAN OPEN-2'],
    'SONY ERICSSON OPEN': [
        'ATP MASTERS 1000 MIAMI',
        'MIAMI OPEN PRESENTED BY ITAU',
        'MIAMI'
    ],
    "BNP PARIBAS OPEN": ['BNP PARIBAS OPEN', 'ATP MASTERS 1000 INDIAN WELLS', 'INDIAN WELLS'],
    "BNP PARIBAS MASTERS": ['BNP PARIBAS MASTERS', 'ATP MASTERS 1000 PARIS', 'PARIS'],
    "INTERNAZIONALI BNL D'ITALIA": [
        "INTERNAZIONALI BNL D'ITALIA",
        "ATP MASTERS 1000 ROME",
        "ROME",
    ],
    "WESTERN & SOUTHERN FINANCIAL GROUP MASTERS": ["WESTERN & SOUTHERN OPEN", "ATP MASTERS 1000 CINCINNATI", "CINCINNATI"],
    "AEGON CHAMPIONSHIPS": "LONDON / QUEEN'S CLUB",
    "MONTE CARLO MASTERS": "ATP MASTERS 1000 MONTE CARLO",
    "MUTUA MADRID OPEN": ["ATP MASTERS 1000 MADRID", "MUTUA MADRID OPEN"],
    "SHANGHAI MASTERS": ["ATP MASTERS 1000 SHANGHAI", "SHANGHAI"],
    "ROGERS MASTERS": ["ATP MASTERS 1000 CANADA", "COUPE ROGERS"],
    "CITI OPEN": ["WASHINGTON", "CITI OPEN"],
    "GERMAN TENNIS CHAMPIONSHIPS": [
        "GERMAN OPEN TENNIS CHAMPIONSHIPS",
        "HAMBURG",
        "ATP MASTERS 1000 HAMBURG",
        "HAMBURG EUROPEAN OPEN"
    ],
    "OPEN BANCO SABADELL": [
        "BARCELONA OPEN BANC SABADELL",
        "BARCELONA",
    ],
    "SWISS INDOORS": "BASEL",
    "RAKUTEN JAPAN OPEN TENNIS CHAMPIONSHIPS": ["RAKUTEN JAPAN OPEN TENNIS CHAMPIONSHIPS", "TOKYO"],
    "QATAR EXXON MOBIL OPEN": ["QATAR EXXONMOBIL OPEN", "DOHA"],
    "GRAND PRIX HASSAN II": "MARRAKECH",
    "GERRY WEBER OPEN": "HALLE",
    "CHINA OPEN": ["CHINA OPEN", "BEIJING"],
    "ABIERTO MEXICANO": ["ABIERTO MEXICANO TELCEL PRESENTADO POR HSBC", "ACAPULCO"],
    "DELRAY BEACH OPEN": ["DELRAY BEACH", "DELRAY BEACH OPEN BY VITACOST.COM"],
    "DUBAI TENNIS CHAMPIONSHIPS": ["DUBAI", "DUBAI DUTY FREE TENNIS CHAMPIONSHIPS"],
    "ERSTE BANK OPEN": ["VIENNA", "ERSTE BANK OPEN"],
    "ARGENTINA OPEN": ["BUENOS AIRES", "ARGENTINA OPEN"],
    "RICOH OPEN": ["S-HERTOGENBOSCH", "'S-HERTOGENBOSCH"],
    "EASTBOURNE INTERNATIONAL": ["EASTBOURNE", "NATURE VALLEY INTERNATIONAL"],
    "BB&T ATLANTA OPEN": ["BB&T ATLANTA OPEN", "ATLANTA"],
    "ASB CLASSIC": ["ASB CLASSIC", "AUCKLAND"],
    "SHENZHEN OPEN": ["SHENZHEN"],
    "SKISTAR SWEDISH OPEN": ["BASTAD", "SWEDISH OPEN"],
    "STOCKHOLM OPEN": ["STOCKHOLM", "INTRUM STOCKHOLM OPEN"],
    "ST. PETERSBURG OPEN": ["ST. PETERSBURG", "ST. PETERSBURG OPEN"],
    "SUISSE OPEN GSTAAD": ["GSTAAD", "J. SAFRA SARASIN SWISS OPEN GSTAAD"],
    "SYDNEY INTERNATIONAL": ["SYDNEY INTERNATIONAL", "SYDNEY"],
    "TATA OPEN": ["TATA OPEN MAHARASHTRA", "PUNE"],
    "U.S. MEN'S CLAY COURT CHAMPIONSHIPS": ["HOUSTON", "FAYEZ SAROFIM & CO. U.S. MEN'S CLAY COURT CHAMPIONSHIP"],
    "ANTALYA OPEN": ["ANTALYA", "TURKISH AIRLINES OPEN ANTALYA"],
    "CROATIA OPEN": ["PLAVA LAGUNA CROATIA OPEN UMAG", "UMAG"],
    "ECUADOR OPEN": "QUITO",
    "GAZPROM HUNGARIAN OPEN": ["HUNGARIAN OPEN", "BUDAPEST"],
    "GENERALI OPEN": ["GENERALI OPEN", "KITZBUHEL", "KITZBÜHEL", "KITZBUEHEL"],
    "OPEN DE MOSELLE": ["MOSELLE OPEN", "METZ"],
    "GENEVA OPEN": ["GENEVA", "BANQUE ERIC STURDZA GENEVA OPEN"],
    "GARANTI KOZA SOFIA OPEN": ["SOFIA", "SOFIA OPEN"],
    "EUROPEAN OPEN": ["ANTWERP", "EUROPEAN OPEN"],
    "HALL OF FAME CHAMPIONSHIPS": ["NEWPORT", "HALL OF FAME OPEN"],
    "ABIERTO MEXICANO MIFEL": ["LOS CABOS", "ABIERTO DE TENIS MIFEL PRESENTADO POR CINEMEX"],
    "ISTANBUL OPEN": "ISTANBUL",
    "KREMLIN CUP": ["MOSCOW", "VTB KREMLIN CUP"],
    "LYON OPEN": ["LYON", "OPEN PARC AUVERGNE-RHONE-ALPES LYON"],
    "MERCEDES CUP": ["STUTTGART", "ATP MASTERS 1000 STUTTGART", "MERCEDESCUP"],
    "MILLENNIUM ESTORIL OPEN": ["ESTORIL", "MILLENNIUM ESTORIL OPEN"],
    "BRASIL OPEN": ["SAO PAULO", "BRASIL OPEN"],
    "CHENGDU OPEN": ["CHENGDU", "CHENGDU OPEN"],
    "NEW YORK OPEN": ["NEW YORK", "NEW YORK OPEN"],
    "OPEN 13": ["OPEN 13 PROVENCE", "MARSEILLE"],
    "BMW OPEN": ["MUNICH", "BMW OPEN BY FWU"],
    "OPEN SUD DE FRANCE": ["OPEN SUD DE FRANCE", "MONTPELLIER"],
    "MASTERS CUP": ["TENNIS MASTERS CUP", "NITTO ATP FINALS"],
    "RIO OPEN": ["RIO DE JANEIRO", "RIO OPEN PRESENTED BY CLARO"],
    "ABN AMRO WORLD TENNIS TOURNAMENT": ["ROTTERDAM", "ABN AMRO WORLD TENNIS TOURNAMENT"],
    "WINSTON-SALEM OPEN AT WAKE FOREST UNIVERSITY": ['WINSTON-SALEM', 'WINSTON-SALEM OPEN']
}

# %% [markdown]
# #### Score Parsing

# %%
WALKOVER_DEFS = [
    'W/O',
    'DEF'
]

def parse_set_score(s):
    if 'RET' in s:
        return ('RETIRE', 'RETIRE')
    elif any([x in s for x in WALKOVER_DEFS]):
        return ('WALKOVER', 'WALKOVER')
    elif 'UNP' in s:
        return ('MATCH_NOT_PLAYED', 'MATCH_NOT_PLAYED')
    else:
        s = s.strip(' (NA)')
        if len(s) == 2:
            return int(s[0]), int(s[1])
        else:
            for b in range(1, len(s)):
                s1, s2 = int(s[:b]), int(s[b:])
                if abs(s1 - s2) <= 2:
                    return s1, s2
            return None, None

# %%
def parse_match_score(s):
    if pd.isnull(s):
        return {}
    set_scores = s.split(';')
    out = {}
    for idx, ss in enumerate(set_scores):
        w, l = parse_set_score(ss)
        out.update({
            'W%d' % (idx + 1): w,
            'L%d' % (idx + 1): l
        })
    return out

# %%
score_df = pd.DataFrame(jd['score'].map(parse_match_score).tolist())

# %%
score_df.head()
# Out:
#   L1 L2 L3   L4   L5 W1 W2 W3   W4   W5
# 0  3  2  6    1  NaN  6  6  5    6  NaN
# 1  3  3  5  NaN  NaN  6  6  6  NaN  NaN
# 2  5  6  4    1  NaN  6  5  6    6  NaN
# 3  2  5  2  NaN  NaN  6  6  6  NaN  NaN
# 4  1  2  4  NaN  NaN  6  6  6  NaN  NaN

# %%
jd = pd.concat([jd, score_df], axis=1)
jd.shape
# Out:
# (373236, 40)

# %%
score_cols = ['W%d' % s for s in range(1, 6)] + ['L%d' % s for s in range(1, 6)]

# %% [markdown]
# #### Joining

# %%
odds_df['odds_match_id'] = range(odds_df.shape[0])

# %%
jd_2018 = jd[jd['year'] == 2018].copy()

# %%
join_cols = sorted([
    'winner_last_name',
    'loser_last_name',
    'tourney_title'
] + score_cols)

# %%
def get_tourney(x, idx):
    mapped = TOURNAMENT_MAPPING[x]
    if isinstance(mapped, str):
        return mapped if idx == 0 else None
    if idx >= len(mapped):
        return None
    else:
        return mapped[idx]

idx = 0
merged_dfs = []
while(True):
    print(idx)
    cur_odds = odds_df.copy()
    cur_odds['tourney_title'] = odds_df['Tournament'].map(lambda x: get_tourney(x, idx))
    if cur_odds['tourney_title'].isnull().all():
         break
    merged_dfs.append(
        pd.merge(
            jd_2018,
            cur_odds,
            on=join_cols
        )
    )
    idx += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
all_merged = pd.concat(merged_dfs)

# %%
all_merged.to_csv("./merged_2018.csv", index=False)

# %%
assert all_merged['match_id'].value_counts().max() == 1

# %%
missing = odds_df[~odds_df['odds_match_id'].isin(all_merged['odds_match_id'].tolist())]

# %%
missing.shape
# Out:
# (82, 43)

# %%
missing['Comment'].value_counts()
# Out:
# Retired     68
# Walkover    14
# Name: Comment, dtype: int64

# %%
missing[missing['Comment'] == 'Completed'][[
    'Winner', 'Loser', 'winner_last_name', 'loser_last_name'
]]
# Out:
# Empty DataFrame
# Columns: [Winner, Loser, winner_last_name, loser_last_name]
# Index: []

# %%
# What tournaments are ALWAYS missing!?
missing[~missing['Tournament'].isin(all_merged['Tournament'])]['Tournament'].value_counts()
# Out:
# Series([], Name: Tournament, dtype: int64)

# %%
missing[missing['Tournament'] == "CHENGDU OPEN"].iloc[0]
# Out:
# ATP                           56
# Location                 Chengdu
# Tournament          CHENGDU OPEN
# Date                     9/25/18
# Series                    ATP250
# Court                    Outdoor
# Surface                     Hard
# Round                  1st Round
# Best of                        3
# Winner              BEMELMANS R.
# Loser                  ZVEREV M.
# WRank                        114
# LRank                         69
# WPts                         492
# LPts                         790
# W1                             6
# L1                             3
# W2                             2
# L2                             0
# W3                           NaN
# L3                           NaN
# W4                           NaN
# L4                           NaN
# W5                           NaN
# L5                           NaN
# Wsets                          1
# Lsets                          0
# Comment                  Retired
# B365W                        1.9
# B365L                        1.8
# EXW                         2.05
# EXL                         1.85
# LBW                            2
# LBL                          1.8
# PSW                         2.08
# PSL                         1.83
# MaxW                         2.1
# MaxL                        1.91
# AvgW                        2.01
# AvgL                        1.81
# winner_last_name       BEMELMANS
# loser_last_name           ZVEREV
# odds_match_id               2264
# Name: 2264, dtype: object

# %%
TOURNAMENT_MAPPING['FRENCH OPEN']
# Out:
# 'ROLAND GARROS'

# %%
get_tourney('FRENCH OPEN', 0)
# Out:
# 'ROLAND GARROS'

# %%
def inspect_match(w=None, l=None):
    if w is not None:
        rel = jd_2018[
            (jd_2018['winner_last_name'] == w)
        ]
    else:
        rel = jd_2018
    if l is not None:
        rel = rel[
            rel['loser_last_name'] == w
        ]
    return rel[[
        'winner_last_name',
        'loser_last_name',
        'tourney_title'
    ] + score_cols]

inspect_match('POLANSKY')
# Out:
#        winner_last_name    loser_last_name                  tourney_title W1  \
# 350999         POLANSKY             PELIWO                       BRISBANE  6
# 351003         POLANSKY           HANFMANN                       BRISBANE  6
# 351474         POLANSKY          DOMINGUES                AUSTRALIAN OPEN  7
# 351528         POLANSKY           HARRISON                AUSTRALIAN OPEN  6
# 352592         POLANSKY  MENENDEZ-MACEIRAS                   DELRAY BEACH  6
# 352984         POLANSKY               KING                   INDIAN WELLS  6
# 353048         POLANSKY             KOZLOV                   INDIAN WELLS  6
# 353242         POLANSKY            AREVALO  ATP MASTERS 1000 INDIAN WELLS  7
# 353253         POLANSKY         BERRETTINI  ATP MASTERS 1000 INDIAN WELLS  6
# 353282         POLANSKY              COPIL  ATP MASTERS 1000 INDIAN WELLS  7
# 353625         POLANSKY             OPELKA         ATP MASTERS 1000 MIAMI  7
# 353900         POLANSKY           ROCHETTE                      LE GOSIER  6
# 354490         POLANSKY           ARGUELLO                       SARASOTA  6
# 354798         POLANSKY        PEDRO SORGI                    TALLAHASSEE  7
# 355864         POLANSKY           MONTEIRO                       BORDEAUX  6
# 356206         POLANSKY             GOMBOS                  ROLAND GARROS  2
# 356265         POLANSKY             KRSTIN                  ROLAND GARROS  6
# 356904         POLANSKY          LOFFHAGEN                     NOTTINGHAM  3
# 356974         POLANSKY             ROBERT                     NOTTINGHAM  6
# 357236         POLANSKY          SANTILLAN                         ILKLEY  6
# 357331         POLANSKY                ITO                         ILKLEY  6
# 357561         POLANSKY               YANG                      WIMBLEDON  4
# 357621         POLANSKY  DAVIDOVICH FOKINA                      WIMBLEDON  7
# 358127         POLANSKY            KRAINIK                       WINNIPEG  7
# 358375         POLANSKY   RODRIGUEZ - PACE                       GATINEAU  7
# 358455         POLANSKY            KRAINIK                       GATINEAU  6
# 358726         POLANSKY          TAKAHASHI                         GRANBY  6
# 358830         POLANSKY                 LI                         GRANBY  6
# 358881         POLANSKY         NAPOLITANO                         GRANBY  7
# 358907         POLANSKY           DANCEVIC                         GRANBY  7
# 358920         POLANSKY            HUMBERT                         GRANBY  6
# 359125         POLANSKY              GALAN                      LOS CABOS  6
# 358920  1       6  NaN  NaN  4  6       2  NaN  NaN
# 359125  3       6  NaN  NaN  4  6       2  NaN  NaN
# 359457  6     NaN  NaN  NaN  6  4     NaN  NaN  NaN
# 359813  5       6  NaN  NaN  6  7       3  NaN  NaN
# 360002  6     NaN  NaN  NaN  4  4     NaN  NaN  NaN
# 360061  6     NaN  NaN  NaN  6  4     NaN  NaN  NaN
# 361083  6       6  NaN  NaN  3  7       1  NaN  NaN
# 361342  6     NaN  NaN  NaN  4  4     NaN  NaN  NaN
# 362191  6     NaN  NaN  NaN  4  1     NaN  NaN  NaN
# 362229  1       6  NaN  NaN  4  6       4  NaN  NaN
# 363002  7     NaN  NaN  NaN  2  5     NaN  NaN  NaN
# 363079  7     NaN  NaN  NaN  5  5     NaN  NaN  NaN
# 363118  6     NaN  NaN  NaN  6  4     NaN  NaN  NaN
# 363136  7     NaN  NaN  NaN  2  6     NaN  NaN  NaN
# 363299  6     NaN  NaN  NaN  2  2     NaN  NaN  NaN
# 363551  6     NaN  NaN  NaN  5  2     NaN  NaN  NaN

# %%
ranked = all_merged[
    all_merged['WRank'].notnull() &
    all_merged['LRank'].notnull()
]

# %%
(ranked['WRank'] < ranked['LRank']).mean()
# Out:
# 0.6354737666405639

# %%
(ranked['B365W'] <= ranked['B365L']).mean()
# Out:
# 0.692247454972592

# %%
(ranked['B365W'] < ranked['B365L']).mean()
# Out:
# 0.6644479248238058

# %%
import numpy as np

with_scores = jd[jd['score'].notnull()]
winner_sets = np.zeros(with_scores.shape[0])
for set_index in range(1, 6):
    winner_sets += (with_scores['W%d' % set_index] > with_scores['L%d' % set_index]).astype(int)

# %%
pd.Series(winner_sets).value_counts()
# Out:
# 2.0    320016
# 3.0     41503
# 0.0      5891
# 1.0      5668
# 4.0         7
# dtype: int64

# %%
with_scores[winner_sets == 1][['score', 'tourney_url_suffix']]
# Out:
#                      score                                 tourney_url_suffix
# 188      46;46;86;20 (RET)      /en/scores/archive/wimbledon/540/1902/results
# 257            62;53 (RET)  /en/scores/archive/australasian-championships/...
# 344      64;46;26;62 (RET)      /en/scores/archive/wimbledon/540/1911/results
# 657            64;64 (RET)  /en/scores/archive/us-championships/560/1914/r...
# 681         61;46;61 (RET)  /en/scores/archive/us-championships/560/1914/r...
# 777            62;62 (RET)  /en/scores/archive/australasian-championships/...
# 793            75;62 (RET)  /en/scores/archive/australasian-championships/...
# 1053        63;26;11 (RET)  /en/scores/archive/us-championships/560/1916/r...
# 1305     46;26;60;35 (RET)  /en/scores/archive/us-championships/560/1919/r...
# 1367           63;61 (RET)  /en/scores/archive/australasian-championships/...
# 1504           61;64 (RET)  /en/scores/archive/us-championships/560/1920/r...
# 1672    62;810;57;42 (RET)      /en/scores/archive/wimbledon/540/1922/results
# 1717           64;64 (RET)      /en/scores/archive/wimbledon/540/1922/results
# 1908        46;62;62 (RET)  /en/scores/archive/us-championships/560/1922/r...
# 1972           63;62 (RET)      /en/scores/archive/wimbledon/540/1923/results
# 2015     26;36;61;31 (RET)      /en/scores/archive/wimbledon/540/1923/results
# 2221           61;60 (RET)      /en/scores/archive/wimbledon/540/1924/results
# 2412           64;63 (RET)  /en/scores/archive/australian-championships/58...
# 2456           75;21 (RET)  /en/scores/archive/australian-championships/58...
# 2522     26;26;64;75 (RET)  /en/scores/archive/french-championships/520/19...
# 3063     63;79;16;62 (RET)  /en/scores/archive/french-championships/520/19...
# 3106        79;64;64 (RET)  /en/scores/archive/french-championships/520/19...
# 3118        46;62;63 (RET)  /en/scores/archive/french-championships/520/19...
# 3125           62;60 (RET)  /en/scores/archive/french-championships/520/19...
# 3251           64;30 (RET)      /en/scores/archive/wimbledon/540/1927/results
# 3359        64;79;64 (RET)  /en/scores/archive/australian-championships/58...
# 3412        36;86;62 (RET)  /en/scores/archive/french-championships/520/19...
# 3422        61;57;97 (RET)  /en/scores/archive/french-championships/520/19...
# 3690     26;68;60;21 (RET)  /en/scores/archive/french-championships/520/19...
# 3920           64;33 (RET)  /en/scores/archive/us-championships/560/1929/r...
# 4009           60;64 (RET)  /en/scores/archive/french-championships/520/19...
# 4012        63;36;64 (RET)  /en/scores/archive/french-championships/520/19...
# 4039           62;62 (RET)  /en/scores/archive/french-championships/520/19...
# 4287           60;62 (RET)  /en/scores/archive/australian-championships/58...
# 4301        36;75;63 (RET)  /en/scores/archive/australian-championships/58...
# 4355        46;61;86 (RET)  /en/scores/archive/french-championships/520/19...
# 4416           63;62 (RET)      /en/scores/archive/wimbledon/540/1931/results
# 4442        64;26;63 (RET)      /en/scores/archive/wimbledon/540/1931/results
# 4688       16;75;108 (W/O)  /en/scores/archive/french-championships/520/19...
# 4762        36;75;01 (RET)      /en/scores/archive/wimbledon/540/1932/results
# 4851           62;23 (RET)      /en/scores/archive/wimbledon/540/1932/results
# 5129           64;53 (RET)      /en/scores/archive/wimbledon/540/1933/results
# 5325        63;46;62 (RET)  /en/scores/archive/french-championships/520/19...
# 5327    36;1210;1211 (RET)  /en/scores/archive/french-championships/520/19...
# 5332           64;75 (RET)  /en/scores/archive/french-championships/520/19...
# 5432     36;46;61;63 (RET)      /en/scores/archive/wimbledon/540/1934/results
# 5698        36;62;60 (RET)  /en/scores/archive/french-championships/520/19...
# 5781     46;46;60;20 (RET)      /en/scores/archive/wimbledon/540/1935/results
# 6152        36;75;26 (RET)      /en/scores/archive/wimbledon/540/1936/results
# 6154        36;63;64 (RET)      /en/scores/archive/wimbledon/540/1936/results
# ...                    ...                                                ...
# 371292         76;00 (RET)     /en/scores/archive/yokkaichi/8268/2019/results
# 371295      26;64;40 (RET)     /en/scores/archive/yokkaichi/8268/2019/results
# 371311         76;00 (RET)      /en/scores/archive/manerbio/9028/2019/results
# 371354      63;36;00 (RET)       /en/scores/archive/montreal/421/2019/results
# 371410      64;57;12 (RET)      /en/scores/archive/augsburg/8266/2019/results
# 371442         64;00 (RET)     /en/scores/archive/yokkaichi/8268/2019/results
# 371443         64;10 (RET)     /en/scores/archive/yokkaichi/8268/2019/results
# 371531         64;00 (RET)     /en/scores/archive/cincinnati/422/2019/results
# 371619         75;10 (RET)      /en/scores/archive/portoroz/6787/2019/results
# 371668      67;76;41 (RET)     /en/scores/archive/cordenons/2120/2019/results
# 371706      46;61;00 (RET)     /en/scores/archive/meerbusch/6809/2019/results
# 371710      76;46;21 (RET)     /en/scores/archive/vancouver/7774/2019/results
# 371749         64;30 (RET)      /en/scores/archive/portoroz/6787/2019/results
# 371782         76;10 (RET)  /en/scores/archive/winston-salem/6242/2019/res...
# 371806         61;00 (RET)  /en/scores/archive/winston-salem/6242/2019/res...
# 371813         63;31 (RET)  /en/scores/archive/winston-salem/6242/2019/res...
# 371816         62;00 (RET)  /en/scores/archive/winston-salem/6242/2019/res...
# 371993         61;41 (RET)        /en/scores/archive/us-open/560/2019/results
# 372127         62;00 (RET)      /en/scores/archive/mallorca/7973/2019/results
# 372172      60;67;11 (RET)          /en/scores/archive/como/3473/2019/results
# 372183      36;76;66 (RET)      /en/scores/archive/mallorca/7973/2019/results
# 372190         62;41 (RET)      /en/scores/archive/mallorca/7973/2019/results
# 372218         61;30 (RET)      /en/scores/archive/mallorca/7973/2019/results
# 372230         63;41 (RET)        /en/scores/archive/baotou/8270/2019/results
# 372235         76;03 (RET)          /en/scores/archive/como/3473/2019/results
# 372296         60;20 (RET)        /en/scores/archive/genova/1763/2019/results
# 372302         62;43 (RET)        /en/scores/archive/genova/1763/2019/results
# 372329         63;10 (RET)         /en/scores/archive/jinan/7746/2019/results
# 372415         76;40 (RET)        /en/scores/archive/cassis/9120/2019/results
# 372502         63;00 (RET)      /en/scores/archive/shanghai/6313/2019/results
# 372570      67;62;21 (RET)      /en/scores/archive/istanbul/7083/2019/results
# 372580      67;63;21 (RET)      /en/scores/archive/istanbul/7083/2019/results
# 372619      26;75;00 (RET)          /en/scores/archive/cary/7316/2019/results
# 372661         62;30 (RET)      /en/scores/archive/istanbul/7083/2019/results
# 372706         76;21 (RET)      /en/scores/archive/shanghai/6313/2019/results
# 372715      67;76;22 (RET)          /en/scores/archive/cary/7316/2019/results
# 372751         76;20 (RET)           /en/scores/archive/metz/341/2019/results
# 372770      75;36;31 (RET)  /en/scores/archive/st-petersburg/568/2019/results
# 372789      67;75;30 (RET)  /en/scores/archive/st-petersburg/568/2019/results
# 372806      57;63;41 (RET)           /en/scores/archive/metz/341/2019/results
# 372817         75;20 (RET)        /en/scores/archive/biella/7085/2019/results
# 372830         61;41 (RET)        /en/scores/archive/biella/7085/2019/results
# 372862      46;62;31 (RET)     /en/scores/archive/kaohsiung/6490/2019/results
# 372962         76;00 (RET)       /en/scores/archive/glasgow/7916/2019/results
# 373050         61;31 (RET)       /en/scores/archive/chengdu/7581/2019/results
# 373070         64;00 (RET)        /en/scores/archive/zhuhai/9164/2019/results
# 373089         62;00 (RET)        /en/scores/archive/zhuhai/9164/2019/results
# 373103      36;75;00 (RET)        /en/scores/archive/zhuhai/9164/2019/results
# 373153         76;41 (RET)         /en/scores/current/beijing/747/live-scores
# 373161         76;10 (RET)         /en/scores/current/beijing/747/live-scores
#
# [5668 rows x 2 columns]

# %%
with_scores[with_scores['score'].map(lambda x: 'W/O' in x)][['winner_name', 'loser_name']]
# Out:
#                        winner_name              loser_name
# 10                    JOHN HARTLEY             FRANK HADOW
# 28                  CLARENCE CLARK            JAMES DWIGHT
# 66                  ERNEST RENSHAW            C. LACYSWEET
# 68                 HERBERT LAWFORD          ERNEST RENSHAW
# 69                 HERBERT LAWFORD         WILLIAM RENSHAW
# 81                    HENRY SLOCUM           RICHARD SEARS
# 101               WILFRED BADDELEY     WILLOUGHBY HAMILTON
# 121                   ROBERT WRENN         OLIVER CAMPBELL
# 122               WILFRED BADDELEY              T. CHAYTOR
# 130               WILFRED BADDELEY        HERBERT BADDELEY
# 133               WILFRED BADDELEY              JOSHUA PIM
# 161                MALCOLM WHITMAN            ROBERT WRENN
# 187                 WILLIAM LARNED         MALCOLM WHITMAN
# 192                 REGGIE DOHERTY        LAURENCE DOHERTY
# 211                  HOLCOMBE WARD        LAURENCE DOHERTY
# 232                RANDOLPH LYCETT           GORDON WRIGHT
# 244                   FRANK FISHER             F. LAISHLEY
# 245                      R. HARMAN                J. SMITH
# 248                     T.R. QUILL            WILLIAM GOSS
# 256                 NORMAN BROOKES        LAURENCE DOHERTY
# 261                  WILLIAM GREGG          UNKNOWN FOWLES
# 279                 WILLIAM LARNED        WILLIAM CLOTHIER
# 283                    ARTHUR GORE          NORMAN BROOKES
# 310                       R. EAGLE          UNKNOWN COOMBE
# 354             ARTHUR O'HARA-WOOD               A. FOSTER
# 372                   J. CARPENTER                G. ADAMS
# 374                      G. CHURCH               J. NELSON
# 377          JAMES STEWART CUSHMAN               J. DOWNEY
# 379                      A. DABNEY               F. HARRIS
# 380                        R. DANA               S. MILLER
# 381                    J. DEVEREUX               H. COLTON
# 382                       R. EVANS              W. ROBERTS
# 384                     C. FRAILEY                C. AMORY
# 387                        W. HALL              H. STINESS
# 388                     A. HAMMETT              C. LEONARD
# 390                     S. HENSHAW            BEALS WRIGHT
# 391                        C. HERD             JERRY WEBER
# 392                     J. HUBBARD              W. PARSONS
# 397                     A. KENNEDY             DEAN MATHEY
# 398                 A. KENNEDY JR.            R. AUSPITZER
# 399                        W. KUHN               H. THOMAS
# 402                 RAYMOND LITTLE            STACEY BROWN
# 403                         A. MAN              E. PICKMAN
# 406                       W. MCKIM              C. LIPSCOM
# 410                NATHANIEL NILES           E. PENDERGAST
# 413                     E. PEASLEE               A. DEVENS
# 416                WHITING PRESTON               H. BRALEY
# 419                   W. ROSENBAUM               W. BOURNE
# 423                     R. STEVENS        C.DRUMMOND JONES
# 425                        V. WARD        F. FRELINGHUYSEN
# ...                            ...                     ...
# 363365               REILLY OPELKA            MICHAEL MMOH
